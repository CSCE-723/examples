# %%
import gymnasium
import math
from gymnasium.envs.classic_control.cartpole import CartPoleEnv
from gymnasium import logger, spaces
import numpy as np
from gymnasium.envs.registration import register

# %%
class SwingPole(CartPoleEnv):
    """https://gymnasium.farama.org/environments/classic_control/cart_pole/"""
    def __init__(self, render_mode: str | None = None):
        super().__init__(render_mode=render_mode)
        self.x_threshold = 3
        self.step_num = 0
        high = np.array(
            [
                self.x_threshold * 2,
                np.finfo(np.float32).max,
                np.finfo(np.float32).max,
                # 4*math.pi,
                np.finfo(np.float32).max,
            ],
            dtype=np.float32,
        )

        self.action_space = spaces.Discrete(2)
        self.observation_space = spaces.Box(-high, high, dtype=np.float32)
    
    def step(self, action):
        obs, rew, _, _, info =  super().step(action)
        self.step_num += 1
        term = False
        x, x_dot, theta, theta_dot = self.state
        term = bool(
            x < -self.x_threshold
            or x > self.x_threshold
            or self.step_num > 1000
            or abs(theta_dot) < 0.01
        )
        rew = theta_dot

        return obs, rew, term, False, info

    def reset(self, *, seed: int | None = None, options: dict | None = None):
        self.step_num = 0
        return super().reset(seed=seed, options=options)

# %%
"""Optionally register the environment to use it with gymnasium.make"""
register(
     id="SwingPole",
     entry_point=SwingPole,
)

env = gymnasium.make("SwingPole", render_mode='rgb_array')
model = None

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

vec_env = make_vec_env(SwingPole, n_envs=10)
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log="./ppo_swingpole_tensorboard/")
model.learn(total_timesteps=100_000, progress_bar=True, tb_log_name="PPO_SwingPole")
model.save("ppo_swingpole")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./ppo_swingpole_tensorboard/PPO_SwingPole_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 120      |
# |    ep_rew_mean     | 338      |
# | time/              |          |
# |    fps             | 1093     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98.1        |
# |    ep_rew_mean          | -34.6       |
# | time/                   |             |
# |    fps                  | 881         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007813991 |
# |    clip_fraction        | 0.0222      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.688      |
# |    explained_variance   | 0.00721     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6e+03     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00436    |
# |    value_loss           | 6.01e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 91.8         |
# |    ep_rew_mean          | -43.4        |
# | time/                   |              |
# |    fps                  | 828          |
# |    iterations           | 3            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0074342806 |
# |    clip_fraction        | 0.00869      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.672       |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.97e+03     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00278     |
# |    value_loss           | 9.9e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 77.2        |
# |    ep_rew_mean          | -28.8       |
# | time/                   |             |
# |    fps                  | 807         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006640072 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 3.3e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 53.9         |
# |    ep_rew_mean          | 63.9         |
# | time/                   |              |
# |    fps                  | 797          |
# |    iterations           | 5            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0147940535 |
# |    clip_fraction        | 0.0742       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.419        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.8e+03      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00845     |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 50.9        |
# |    ep_rew_mean          | 149         |
# | time/                   |             |
# |    fps                  | 790         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008108282 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.491      |
# |    explained_variance   | 0.438       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+03    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 3.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.1        |
# |    ep_rew_mean          | 210         |
# | time/                   |             |
# |    fps                  | 785         |
# |    iterations           | 7           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.009069415 |
# |    clip_fraction        | 0.081       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 3.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 43.1        |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 8           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.003796116 |
# |    clip_fraction        | 0.0512      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.375      |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.45e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00465    |
# |    value_loss           | 3.2e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 43.8       |
# |    ep_rew_mean          | 228        |
# | time/                   |            |
# |    fps                  | 770        |
# |    iterations           | 9          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01381867 |
# |    clip_fraction        | 0.091      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.371     |
# |    explained_variance   | 0.384      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 2.86e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 45.3        |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 762         |
# |    iterations           | 10          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007669804 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.398      |
# |    explained_variance   | 0.406       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 2.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.5        |
# |    ep_rew_mean          | 267         |
# | time/                   |             |
# |    fps                  | 758         |
# |    iterations           | 11          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.005989754 |
# |    clip_fraction        | 0.0727      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.408      |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00516    |
# |    value_loss           | 2.99e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 48.2        |
# |    ep_rew_mean          | 279         |
# | time/                   |             |
# |    fps                  | 755         |
# |    iterations           | 12          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.005721016 |
# |    clip_fraction        | 0.0715      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.418      |
# |    explained_variance   | 0.526       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0077     |
# |    value_loss           | 2.95e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 48.5         |
# |    ep_rew_mean          | 286          |
# | time/                   |              |
# |    fps                  | 753          |
# |    iterations           | 13           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0045236307 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.416       |
# |    explained_variance   | 0.525        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00489     |
# |    value_loss           | 3.01e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 49.8        |
# |    ep_rew_mean          | 299         |
# | time/                   |             |
# |    fps                  | 752         |
# |    iterations           | 14          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005041398 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.409      |
# |    explained_variance   | 0.564       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.61e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00745    |
# |    value_loss           | 2.97e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 53.6        |
# |    ep_rew_mean          | 327         |
# | time/                   |             |
# |    fps                  | 750         |
# |    iterations           | 15          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.005428772 |
# |    clip_fraction        | 0.0493      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.394      |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.57e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00756    |
# |    value_loss           | 3.31e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 58.5        |
# |    ep_rew_mean          | 351         |
# | time/                   |             |
# |    fps                  | 746         |
# |    iterations           | 16          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.003935137 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 0.472       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.75e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00683    |
# |    value_loss           | 3.94e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 66.2         |
# |    ep_rew_mean          | 403          |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 17           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0034088981 |
# |    clip_fraction        | 0.0195       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.356       |
# |    explained_variance   | 0.562        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.39e+03     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00366     |
# |    value_loss           | 4.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 74.9         |
# |    ep_rew_mean          | 462          |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 18           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0012455769 |
# |    clip_fraction        | 0.00967      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.34        |
# |    explained_variance   | 0.288        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.69e+03     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 5.79e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 85.5        |
# |    ep_rew_mean          | 545         |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 19          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.003916925 |
# |    clip_fraction        | 0.0197      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.334      |
# |    explained_variance   | 0.459       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.04e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00186    |
# |    value_loss           | 6.73e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.7        |
# |    ep_rew_mean          | 620         |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 20          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004004268 |
# |    clip_fraction        | 0.0457      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.343      |
# |    explained_variance   | 0.36        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.73e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 7.95e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 104          |
# |    ep_rew_mean          | 705          |
# | time/                   |              |
# |    fps                  | 745          |
# |    iterations           | 21           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0024636947 |
# |    clip_fraction        | 0.0163       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.344       |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.25e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000488    |
# |    value_loss           | 6.67e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 110         |
# |    ep_rew_mean          | 768         |
# | time/                   |             |
# |    fps                  | 745         |
# |    iterations           | 22          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.004103278 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.32       |
# |    explained_variance   | 0.427       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00244    |
# |    value_loss           | 7.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 802         |
# | time/                   |             |
# |    fps                  | 744         |
# |    iterations           | 23          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011248082 |
# |    clip_fraction        | 0.0515      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.341      |
# |    explained_variance   | 0.496       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.68e+03    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00341    |
# |    value_loss           | 7.27e+03    |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 111           |
# |    ep_rew_mean          | 809           |
# | time/                   |               |
# |    fps                  | 744           |
# |    iterations           | 24            |
# |    time_elapsed         | 66            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00051016326 |
# |    clip_fraction        | 0.00229       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.361        |
# |    explained_variance   | 0.504         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.45e+03      |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -5.56e-05     |
# |    value_loss           | 7.74e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 111          |
# |    ep_rew_mean          | 833          |
# | time/                   |              |
# |    fps                  | 743          |
# |    iterations           | 25           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0066124876 |
# |    clip_fraction        | 0.0579       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.402       |
# |    explained_variance   | 0.542        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.87e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00234     |
# |    value_loss           | 6.57e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 111         |
# |    ep_rew_mean          | 855         |
# | time/                   |             |
# |    fps                  | 743         |
# |    iterations           | 26          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.008224984 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.413      |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.39e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00578    |
# |    value_loss           | 8.29e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 113          |
# |    ep_rew_mean          | 884          |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 27           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0018070237 |
# |    clip_fraction        | 0.0187       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.433       |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.78e+03     |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 8.46e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | 909          |
# | time/                   |              |
# |    fps                  | 742          |
# |    iterations           | 28           |
# |    time_elapsed         | 77           |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0016107516 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.435       |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.55e+03     |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000435    |
# |    value_loss           | 7.91e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 117          |
# |    ep_rew_mean          | 932          |
# | time/                   |              |
# |    fps                  | 740          |
# |    iterations           | 29           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0073703006 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.428       |
# |    explained_variance   | 0.617        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.83e+03     |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00724     |
# |    value_loss           | 8.35e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 121        |
# |    ep_rew_mean          | 991        |
# | time/                   |            |
# |    fps                  | 739        |
# |    iterations           | 30         |
# |    time_elapsed         | 83         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00476218 |
# |    clip_fraction        | 0.0508     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.429     |
# |    explained_variance   | 0.655      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.9e+03    |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00389   |
# |    value_loss           | 7.71e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 130          |
# |    ep_rew_mean          | 1.09e+03     |
# | time/                   |              |
# |    fps                  | 739          |
# |    iterations           | 31           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0049044467 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.455       |
# |    explained_variance   | 0.605        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.19e+03     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00466     |
# |    value_loss           | 9.27e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 142         |
# |    ep_rew_mean          | 1.18e+03    |
# | time/                   |             |
# |    fps                  | 738         |
# |    iterations           | 32          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005371584 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.538      |
# |    explained_variance   | 0.391       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.43e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00412    |
# |    value_loss           | 9.31e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 157          |
# |    ep_rew_mean          | 1.34e+03     |
# | time/                   |              |
# |    fps                  | 735          |
# |    iterations           | 33           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0044915993 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.547       |
# |    explained_variance   | 0.695        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.2e+03      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.0037      |
# |    value_loss           | 1.01e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | 1.42e+03    |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 34          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004832982 |
# |    clip_fraction        | 0.0338      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.598      |
# |    explained_variance   | 0.17        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.91e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00346    |
# |    value_loss           | 1.45e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 1.5e+03     |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 35          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008250982 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.622      |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.76e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.000974   |
# |    value_loss           | 7.68e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 204         |
# |    ep_rew_mean          | 1.71e+03    |
# | time/                   |             |
# |    fps                  | 734         |
# |    iterations           | 36          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005461157 |
# |    clip_fraction        | 0.0432      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.0941      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.7e+03     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00231    |
# |    value_loss           | 9.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 215         |
# |    ep_rew_mean          | 1.82e+03    |
# | time/                   |             |
# |    fps                  | 733         |
# |    iterations           | 37          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.005648016 |
# |    clip_fraction        | 0.0302      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.59       |
# |    explained_variance   | 0.0497      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.66e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00264    |
# |    value_loss           | 1.77e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 232        |
# |    ep_rew_mean          | 2.01e+03   |
# | time/                   |            |
# |    fps                  | 732        |
# |    iterations           | 38         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00850537 |
# |    clip_fraction        | 0.0564     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.609     |
# |    explained_variance   | 0.419      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.03e+04   |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.00529   |
# |    value_loss           | 2.05e+04   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 249          |
# |    ep_rew_mean          | 2.2e+03      |
# | time/                   |              |
# |    fps                  | 731          |
# |    iterations           | 39           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0034904364 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.287        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.94e+03     |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00522     |
# |    value_loss           | 1.76e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 261         |
# |    ep_rew_mean          | 2.35e+03    |
# | time/                   |             |
# |    fps                  | 731         |
# |    iterations           | 40          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009255463 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.591      |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.06e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00211    |
# |    value_loss           | 1.84e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 276         |
# |    ep_rew_mean          | 2.46e+03    |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 41          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.009071875 |
# |    clip_fraction        | 0.0458      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.0257      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.04e+04    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.000258    |
# |    value_loss           | 1.96e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 294          |
# |    ep_rew_mean          | 2.66e+03     |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 42           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0030672248 |
# |    clip_fraction        | 0.0211       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.622       |
# |    explained_variance   | 0.504        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.02e+03     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00338     |
# |    value_loss           | 1.42e+04     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 317         |
# |    ep_rew_mean          | 2.86e+03    |
# | time/                   |             |
# |    fps                  | 728         |
# |    iterations           | 43          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.008968305 |
# |    clip_fraction        | 0.0288      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.483       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.82e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 1.51e+04    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 3.08e+03     |
# | time/                   |              |
# |    fps                  | 728          |
# |    iterations           | 44           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0022732697 |
# |    clip_fraction        | 0.0106       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.62        |
# |    explained_variance   | 0.442        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.63e+04     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000969    |
# |    value_loss           | 2.83e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 351          |
# |    ep_rew_mean          | 3.17e+03     |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 45           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018399324 |
# |    clip_fraction        | 0.0576       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.0124       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.88e+03     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | 0.0004       |
# |    value_loss           | 1.9e+04      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 366          |
# |    ep_rew_mean          | 3.35e+03     |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 46           |
# |    time_elapsed         | 129          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0038898971 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.63        |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.51e+03     |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00171     |
# |    value_loss           | 1.66e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 383          |
# |    ep_rew_mean          | 3.57e+03     |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 47           |
# |    time_elapsed         | 132          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0054277317 |
# |    clip_fraction        | 0.0608       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.623       |
# |    explained_variance   | 0.0537       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.32e+04     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00158     |
# |    value_loss           | 2.74e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 405          |
# |    ep_rew_mean          | 3.83e+03     |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 48           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0036039692 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.634       |
# |    explained_variance   | 0.0464       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.11e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | 0.00121      |
# |    value_loss           | 2.23e+04     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 422          |
# |    ep_rew_mean          | 4.08e+03     |
# | time/                   |              |
# |    fps                  | 727          |
# |    iterations           | 49           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0075796563 |
# |    clip_fraction        | 0.0375       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.607       |
# |    explained_variance   | 0.395        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+04      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00493     |
# |    value_loss           | 3.18e+04     |
# ------------------------------------------

# %%
"""Here is one episode using the trained algorithm to show a pygame episode"""
from time import sleep
episode_reward = 0
reward = 0
step = 0
env2 = SwingPole(render_mode='human') # get the environment from the model
obs, info = env2.reset()
terminated = truncated = False
while not terminated and not truncated:
    action = model.predict(obs, deterministic=True)[0]  # use the trained model to predict the action
    obs, reward, terminated, truncated, info = env2.step(action)
    episode_reward += reward
    env2.render()
    step += 1
    sleep(0.0001)  # sleep to slow down the rendering a bit

print('episode reward was: ', episode_reward)
print('steps taken: ', step)
env2.close()
# Out:
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/classic_control/cartpole.py:214: UserWarning: WARN: You are calling 'step()' even though this environment has already returned terminated = True. You should always call 'reset()' once you receive 'terminated = True' -- any further steps are undefined behavior.
#   logger.warn(
# episode reward was:  14571.514995381593
# steps taken:  1001

# %%
"""Here is one episode using the trained algorithm to show a pygame episode"""
import moviepy as mpy
episode_reward = 0
reward = 0
step = 0
img_list = []
env2 = SwingPole(render_mode='rgb_array') # get the environment from the model
obs, info = env2.reset()
terminated = truncated = False
while not terminated and not truncated:
    action = model.predict(obs, deterministic=True)[0]  # use the trained model to predict the action
    obs, reward, terminated, truncated, info = env2.step(action)
    episode_reward += reward
    img_list.append(env2.render())
    step += 1

print('episode reward was: ', episode_reward)
print('steps taken: ', step)
clip = mpy.ImageSequenceClip(img_list, fps=30)
clip.write_videofile("cartswing_episode.mp4")
# Out:
# episode reward was:  14698.70725315298
# steps taken:  1001
# MoviePy - Building video cartswing_episode.mp4.
# MoviePy - Writing video cartswing_episode.mp4
# MoviePy - Done !
# MoviePy - video ready cartswing_episode.mp4
